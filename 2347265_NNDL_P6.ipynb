# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Load data and strip whitespace from column names
data = pd.read_csv("HistoricalQuotes.csv")
data.columns = data.columns.str.strip()

data['Close/Last'] = data['Close/Last'].replace('[\$,]', '', regex=True).astype(float)

data.rename(columns={'Close/Last': 'Close'}, inplace=True)

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data['Close'] = scaler.fit_transform(data[['Close']])
training_size = int(len(data) * 0.8)
train_data, test_data = data[:training_size], data[training_size:]

# %%
import numpy as np

def create_sequences(data, sequence_length=60):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i + sequence_length])
        y.append(data[i + sequence_length])
    return np.array(X), np.array(y)

# Ensure data is a Series (or a 1D array)
sequence_length = 60
train_data = train_data['Close'].values  # Convert to array if not already
test_data = test_data['Close'].values    # Convert to array if not already

# Create sequences
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Build model
model = Sequential([
    SimpleRNN(50, return_sequences=False, input_shape=(X_train.shape[1], 1)),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0674 - val_loss: 8.8677e-05
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0222e-04 - val_loss: 7.7507e-05
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6200e-04 - val_loss: 7.5151e-05
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.4852e-04 - val_loss: 9.8193e-05
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7557e-04 - val_loss: 6.3485e-05
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.2863e-04 - val_loss: 5.0645e-05
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 2.4438e-04 - val_loss: 7.6555e-05
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1378e-04 - val_loss: 8.1494e-05
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2697e-04 - val_loss: 4.8256e-05
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.8136e-04 - val_loss: 5.5287e-05
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6791e-04 - val_loss: 3.6173e-05
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5289e-04 - val_loss: 5.5372e-05
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0762e-04 - val_loss: 9.3387e-05
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7899e-04 - val_loss: 2.6897e-05
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9925e-04 - val_loss: 3.3741e-05
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4831e-04 - val_loss: 4.3542e-05
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4706e-04 - val_loss: 4.9589e-05
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3548e-04 - val_loss: 2.6410e-05
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3178e-04 - val_loss: 2.1169e-05
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.1760e-04 - val_loss: 2.0217e-05
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1321e-04 - val_loss: 2.5554e-05
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.1797e-04 - val_loss: 2.6200e-05
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1528e-04 - val_loss: 2.1559e-05
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0964e-04 - val_loss: 2.1310e-05
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0915e-04 - val_loss: 1.7976e-05
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0149e-04 - val_loss: 2.1660e-05
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.3404e-05 - val_loss: 2.6151e-05
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7513e-04 - val_loss: 1.7245e-05
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0780e-04 - val_loss: 2.9258e-05
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0366e-04 - val_loss: 1.4665e-05
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.2212e-05 - val_loss: 1.6610e-05
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 9.1397e-05 - val_loss: 3.2775e-05
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.0512e-05 - val_loss: 1.9904e-05
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.3599e-05 - val_loss: 4.3662e-05
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1117e-04 - val_loss: 1.5493e-05
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1043e-04 - val_loss: 2.0139e-05
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.3202e-05 - val_loss: 1.5966e-05
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.7087e-05 - val_loss: 1.2337e-05
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.2182e-05 - val_loss: 1.3232e-05
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.2292e-05 - val_loss: 1.5280e-05
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7160e-05 - val_loss: 1.5811e-05
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.5240e-05 - val_loss: 1.1990e-05
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.5739e-05 - val_loss: 1.7730e-05
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.3829e-05 - val_loss: 6.1197e-05
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 1.2547e-04 - val_loss: 1.3670e-05
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.9164e-05 - val_loss: 1.9358e-05
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.9643e-05 - val_loss: 2.0451e-05
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1366e-04 - val_loss: 1.3445e-05
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.7909e-05 - val_loss: 1.0841e-05
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7997e-05 - val_loss: 1.2954e-05

# %%
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)
y_test = y_test.reshape(-1, 1)  # Reshape y_test for inverse transformation
actual_prices = scaler.inverse_transform(y_test)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
# Reshape y_test to be two-dimensional
y_test = y_test.reshape(-1, 1)

# Perform inverse scaling
actual_prices = scaler.inverse_transform(y_test)

# Plotting
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))
plt.plot(actual_prices, color="black", label="Actual Price")
plt.plot(predicted_prices, color="green", label="Predicted Price")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.title("AAPL Stock Price Prediction")
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(actual_prices, predicted_prices)
rmse = np.sqrt(mean_squared_error(actual_prices, predicted_prices))

print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 0.8229131013131359
# Root Mean Squared Error (RMSE): 1.0702628958530782

# %% [markdown]
# **Report**

# %% [markdown]
# **Stock Price Prediction Using RNN for AAPL Stock**
#
# In this project, we built a Recurrent Neural Network (RNN) model to predict Apple Inc.'s future stock prices based on historical data from 2005 to 2017. By focusing solely on the "Close" price of each day, we aimed to predict the next day's stock price based on a sequence of the previous 60 days' closing prices. The RNN model was built using TensorFlow/Keras, trained with mean squared error (MSE) loss, and optimized using the Adam optimizer.

# %% [markdown]
# **Results**
#
#
# The model achieved promising results, with the predicted stock prices closely following the general trends of the actual stock prices. The plot of actual vs. predicted prices shows that the model successfully captured overall price movements over time, indicating a reasonable degree of accuracy in short-term predictions. Key metrics like Mean Absolute Error (MAE) and Root Mean Squared Error (RMSE) provided quantitative measures of the model's performance, highlighting its capability to produce predictions with minimal error.

# %% [markdown]
# **Limitations and Challenges**
#
# **Limited Data Scope**: This model is trained only on data up to 2017, which limits its ability to make accurate predictions for recent market conditions. Including newer data would make the model more relevant to current trends.
#
# **Simple Model Structure**: A basic RNN model with one layer may struggle to capture complex patterns in stock price movements. More advanced models like LSTM or GRU, which can handle long-term dependencies better, might improve accuracy by capturing the non-linear patterns often seen in stock markets.
#
# **Sequence Length Sensitivity**: The chosen sequence length (60 days) can affect the model’s ability to capture trends. Changing this length could improve or worsen the model’s performance, and testing different lengths might yield better results.
#
# **Lack of Context for Market Changes**: Stock prices are influenced by many factors beyond past prices, like economic news and global events. Since this model uses only historical prices, it may perform poorly during unpredictable market shifts, where other external data would provide helpful context.
